# %% [markdown]
# <a href="https://colab.research.google.com/github/VinayaSharada/KateelLearningDemosToStudents/blob/main/DomainUseCaseDemos/Banking/BankQ/QueueManagementDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Queue Design and Management Demo Using Synthetic Data
#
# This notebook analyzes the queue data generated by the synthetic data generator.
#
# It demonstrates queue metrics calculation, visualizations, and management insights relevant to bank branch queue operations.
#
# ### Features:
# - Read synthetic queue data from `syntheticdata.csv`
# - Calculate wait times, service times, and summarize metrics
# - Visualize wait time distributions and hourly arrival/service counts
# - Provide actionable insights for queue management in banks
#
# ---
#
# ## How to use:
# 1. Ensure `syntheticdata.csv` is available in this folder (generate it with `SyntheticDataGenerator.ipynb` if needed).
# 2. Run all cells to see analysis results and graphs.
# 3. Modify or extend analysis for research or operational use.

# %%
# Install dependencies (if running in Colab or fresh environment)
# !pip install pandas matplotlib seaborn --quiet

# %% [markdown]
# ## Step-by-Step Explanation
#
# ### What this cell is doing
# 1. Installs or refreshes the package dependencies needed for the notebook run.
# 2. Key code cues in this cell include `!pip install pandas matplotlib seaborn --quiet` and related statements.
#
# ### How to interpret the result
# - A successful result here means the environment is ready; failures usually point to missing internet access or package-version conflicts.
# - Ask students what business decision would change if this output moved materially up, down, or in an unexpected direction.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step-by-Step Explanation
#
# ### What this cell is doing
# 1. Imports the Python libraries that support data handling, modeling, or visualization in the next steps.
# 2. Key code cues in this cell include `import pandas as pd`, which sets the direction for the rest of the cell.
#
# ### How to interpret the result
# - Use the imported library list to explain which tools are responsible for tables, charts, and model behavior later in the notebook.
# - Ask students what business decision would change if this output moved materially up, down, or in an unexpected direction.

# %%
def load_data(file='syntheticdata.csv'):
    try:
        df = pd.read_csv(file, parse_dates=['arrival_time', 'service_start_time'])
        return df
    except Exception as e:
        print(f"Error loading data file: {e}")
        return None

# %% [markdown]
# ## Step-by-Step Explanation
#
# ### What this cell is doing
# 1. Loads or generates the dataset that the rest of the analysis depends on.
# 2. Defines reusable logic so the notebook can repeat the same analysis consistently across scenarios.
# 3. Shows an immediate checkpoint so students can verify that the previous transformation worked as expected.
# 4. Key code cues in this cell include `def load_data(file='syntheticdata.csv'):`, which sets the direction for the rest of the cell.
#
# ### How to interpret the result
# - Review the rows and columns carefully because this dataset defines what the model or analysis is allowed to learn from.
# - A function definition does not usually produce business output yet; the important question is what inputs it expects and what output it will later generate.
# - Ask students what business decision would change if this output moved materially up, down, or in an unexpected direction.

# %%
def analyze_queue(df):
    """
    Calculate wait times and basic queue stats.
    """
    df['wait_time_sec'] = (df['service_start_time'] - df['arrival_time']).dt.total_seconds()
    stats = {
        'avg_wait_time_sec': df['wait_time_sec'].mean(),
        'median_wait_time_sec': df['wait_time_sec'].median(),
        'max_wait_time_sec': df['wait_time_sec'].max(),
        'avg_service_time_sec': df['service_duration_sec'].mean(),
        'total_customers': len(df),
    }
    return stats, df

# %% [markdown]
# ## Step-by-Step Explanation
#
# ### What this cell is doing
# 1. Defines reusable logic so the notebook can repeat the same analysis consistently across scenarios.
# 2. Key code cues in this cell include `def analyze_queue(df):`, which sets the direction for the rest of the cell.
#
# ### How to interpret the result
# - A function definition does not usually produce business output yet; the important question is what inputs it expects and what output it will later generate.
# - Ask students what business decision would change if this output moved materially up, down, or in an unexpected direction.

# %%
def plot_wait_times(df):
    plt.figure(figsize=(10,6))
    sns.histplot(df['wait_time_sec'], bins=50, kde=True, color='skyblue')
    plt.title('Distribution of Customer Wait Times (seconds)')
    plt.xlabel('Wait Time (seconds)')
    plt.ylabel('Number of Customers')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Step-by-Step Explanation
#
# ### What this cell is doing
# 1. Defines reusable logic so the notebook can repeat the same analysis consistently across scenarios.
# 2. Creates a chart so learners can inspect structure, trend, dispersion, or risk visually.
# 3. Key code cues in this cell include `def plot_wait_times(df):`, which sets the direction for the rest of the cell.
#
# ### How to interpret the result
# - A function definition does not usually produce business output yet; the important question is what inputs it expects and what output it will later generate.
# - The right interpretation is usually about relative shape, outliers, and direction of movement rather than memorizing exact pixel-level detail.
# - Ask students what business decision would change if this output moved materially up, down, or in an unexpected direction.

# %%
def plot_service_over_time(df):
    df['arrival_hour'] = df['arrival_time'].dt.hour
    df['service_start_hour'] = df['service_start_time'].dt.hour

    plt.figure(figsize=(12,6))
    sns.countplot(x='arrival_hour', data=df, color='orange', alpha=0.6)
    sns.countplot(x='service_start_hour', data=df, color='blue', alpha=0.6)
    plt.legend(['Arrival Time', 'Service Start Time'])
    plt.title('Hourly Distribution of Customer Arrivals and Service Start')
    plt.xlabel('Hour of Day')
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# ## Step-by-Step Explanation
#
# ### What this cell is doing
# 1. Defines reusable logic so the notebook can repeat the same analysis consistently across scenarios.
# 2. Creates a chart so learners can inspect structure, trend, dispersion, or risk visually.
# 3. Key code cues in this cell include `def plot_service_over_time(df):`, which sets the direction for the rest of the cell.
#
# ### How to interpret the result
# - A function definition does not usually produce business output yet; the important question is what inputs it expects and what output it will later generate.
# - The right interpretation is usually about relative shape, outliers, and direction of movement rather than memorizing exact pixel-level detail.
# - Ask students what business decision would change if this output moved materially up, down, or in an unexpected direction.

# %%
def run_demo():
    print("Loading synthetic data...")
    df = load_data()
    if df is None:
        print("Data loading failed. Please generate syntheticdata.csv first.")
        return

    print("Analyzing queue data...")
    stats, df = analyze_queue(df)

    print("\nQueue Analysis Summary:")
    print(f"Total customers served: {stats['total_customers']}")
    print(f"Average wait time (sec): {stats['avg_wait_time_sec']:.2f}")
    print(f"Median wait time (sec): {stats['median_wait_time_sec']:.2f}")
    print(f"Maximum wait time (sec): {stats['max_wait_time_sec']:.2f}")
    print(f"Average service duration (sec): {stats['avg_service_time_sec']:.2f}")

    print("\nGenerating plots...")
    plot_wait_times(df)
    plot_service_over_time(df)

    print("\nManagement Insights:")
    print("""
    1. Average wait time helps determine if the current number of tellers meets customer demand.
    2. Peak arrival hours identified can be used to allocate additional staff.
    3. Maximum wait time indicates if service levels meet acceptable limits or require improvement.
    4. Distribution of wait times gives insight into congestion and service variability.
    5. Transaction type and amount analysis (future extensions) can optimize priority handling.
    """)

run_demo()

# %% [markdown]
# ## Step-by-Step Explanation
#
# ### What this cell is doing
# 1. Loads or generates the dataset that the rest of the analysis depends on.
# 2. Defines reusable logic so the notebook can repeat the same analysis consistently across scenarios.
# 3. Shows an immediate checkpoint so students can verify that the previous transformation worked as expected.
# 4. Key code cues in this cell include `def run_demo():`, which sets the direction for the rest of the cell.
#
# ### How to interpret the result
# - Review the rows and columns carefully because this dataset defines what the model or analysis is allowed to learn from.
# - A function definition does not usually produce business output yet; the important question is what inputs it expects and what output it will later generate.
# - Ask students what business decision would change if this output moved materially up, down, or in an unexpected direction.
